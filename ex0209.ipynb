# %%
# !pip install requests

# %%
import requests
a=requests.get(
'http://ggoreb.com/dinosaur/info.jsp'
)

# %%
a=a.json()

# %%
for index in range(len(a)):
    for i in a:
        print(i.get('kind'))
# Out:
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새

# %%
a[0]['dinosaurs']
# Out:
# [{'imgs': ['carnivorous/갈리미무스1.jpg',
#    'carnivorous/갈리미무스2.jpg',
#    'carnivorous/갈리미무스3.png'],
#   'title': '갈리미무스',
#   'search': '공룡 갈리미무스',
#   'description': "중생대 백악기 후기 몽골에서 살았던 수각류 공룡으로 속명의 뜻은 '닭 모사물'이란 뜻이지만 실제로는 목과 다리가 길어 닭보다는 오히려 타조나 에뮤와 비슷한 모습을 띄고있다. 잘 알려져 있듯, 긴 다리로 질주하여 도망쳤다. 워낙 빨라 타르보사우루스같은 대형종이 잡기에는 약간 무리가 있었다.\n\n오르니토미무스류 중에서는 특히 대형이며 가장 잘 알려진 종류 중 하나다. 한동안 다른 오르니토미무스류 공룡들과 마찬가지로 식물, 열매, 작은 동물등을 먹는 초식 성향이 강한 잡식성으로 생각되었지만, 잘 보존된 화석의 부리에서 오늘날의 플라밍고와 비슷한 여과장치가 발견되어 플라밍고처럼 작은 먹이를 여과해서 먹었을지도 모른다는 의견이 제시되었다."},
#  {'imgs': ['carnivorous/고르고사우루스1.png',
#    'carnivorous/고르고사우루스2.jpg',
#    'carnivorous/고르고사우루스3.jpg',
#    'carnivorous/고르고사우루스4.jpg'],
#   'title': '고르고사우루스',
#   'search': '공룡 고르고사우루스',
# ...

# %%
for re in a:
    kind = re['kind']
    print(kind)
# Out:
# 육식공룡
# 초식공룡
# 익룡
# 어룡
# 수장룡
# 시조새

# %% [raw]
# af=a.get(dinosaurs)
# print(af)

# %%
for dinosaur in a:
    dinosaurs = dinosaur.get('dinosaurs')
    for dino in dinosaurs:
        title = dino.get('title')
        print(title)
# Out:
# 갈리미무스
# 고르고사우루스
# 기가노토사우루스
# 기간토랍토르
# 다스플레토사우루스
# 데이노니쿠스
# 데이노케이루스
# 드로마에오사우루스
# 딜로포사우루스
# 메갈로사우루스
# 모노로포사우루스
# 미크로랍토르
# 바리오닉스
# 벨로키랍토르
# 사우로르니토이데스
# 수코미무스
# 스트루티오미무스
# 스피노사우루스
# 시노사우롭테릭스
# 아크로칸토사우루스
# 알렉트로사우루스
# 알로사우루스
# 알리오라무스
# 알베르토사우루스
# 양추아노사우루스
# 에오랍토르
# 오르니토미무스
# 오르니톨레스테스
# 오비랍토르
# 유타랍토르
# 카르노타우루스
# 카르카로돈토사우루스
# 카우딥테릭스
# 케라토사우루스
# 코엘로피시스
# 콤프소그나투스
# 크리올로포사우루스
# 타르보사우루스
# 트로오돈
# 티라노사우루스
# 플라테오사우루스
# 헤레라사우루스
# 그라킬리케라톱스
# 네메그토사우루스
# 노도사우루스
# 드리오사우루스
# 디플로도쿠스
# 람베오사우루스
# 레소토사우루스
# 레아엘리나사우라
# 렉소비사우루스
# 렙토케라톱스
# 롱기스쿠아마
# 루펜고사우루스
# 리오자사우루스
# 마멘키사우루스
# 마이아사우라
# 모노클로니우스
# 몬타노케라톱스
# 무스사우루스
# 무타부라사우루스
# 민미
# 바라파사우루스
# 바로사우루스
# 박트로사우루스
# 브라키오사우루스
# 사우로펠타
# 사우롤로푸스
# 산퉁고사우루스
# 살타사우루스
# 세이스모사우루스
# 슈노사우루스
# 스켈리도사우루스
# 스쿠텔로사우루스
# 스테고사우루스
# 스테고케라스
# 스티기몰로크
# 스티라코사우루스
# 아르헨티노사우루스
# 아마르가사우루스
# 아파토사우루스
# 안키사우루스
# 안킬로사우루스
# 알라모사우루스
# 암펠로사우루스
# 에드몬토사우루스
# 오우라노사우루스
# 올리고키푸스
# 이구아노돈
# 친타오사우루스
# 카마라사우루스
# 카스모사우루스
# 칸네메예리아
# 캄프토사우루스
# 케티오사우루스
# 켄트로사우루스(각룡)
# 켄트로사우루스(검룡)
# 코리토사우루스
# 크리토사우루스
# 테논토사우루스
# ...

# %%
b=requests.get(
'http://ggoreb.com/api/shop.jsp'
)

# %%
result = b.json()

# %%
items=result.get('list')
items
# Out:
# [{'id': 1,
#   'address': '경기 용인시 수지구 광교중앙로 297 D동 107호 (상현동, 광교2차푸르지오시티)',
#   'name': '세이브 코스트',
#   'lng': 127.06861385175,
#   'lat': 37.2967198664476,
#   'kind': '신변잡화-기타잡화'},
#  {'id': 2,
#   'address': '경기 용인시 처인구 명지로 191층 (역북동)',
#   'name': '길이네보리손칼국수',
#   'lng': 127.1890469867,
#   'lat': 37.234316688001,
#   'kind': '일반휴게음식-일반한식'},
#  {'id': 3,
#   'address': '경기 용인시 수지구 포은대로 313번길 8지상에이동부림갈비(풍덕천동)',
#   'name': '석기정돌솥부대찌게',
#   'lng': 0.0,
#   'lat': 0.0,
#   'kind': '일반휴게음식-일반한식'},
#  {'id': 4,
#   'address': '경기 용인시 기흥구 마북동 554-10,1칸',
#   'name': '에이스컴퓨터',
#   'lng': 127.106124967698,
#   'lat': 37.3029740213321,
#   'kind': '사무통신-통신기기'},
#  {'id': 5,
#   'address': '경기 용인시 기흥구 한보라2로 5-9,4층 403호 (보라동)',
#   'name': '분트쿤스트슐레미술학원',
#   'lng': 127.110523825053,
#   'lat': 37.254704374952,
#   'kind': '학원-예•체능계학원'},
#  {'id': 6,
#   'address': '경기 용인시 처인구 양지면 남곡로 48',
#   'name': '피씨퍼니처 주식회사',
#   'lng': 127.282100411513,
#   'lat': 37.2296719610395,
# ...

# %%
for item in items:
    lat = item.get('lat')
    lng = item.get('lng')
    print(lat,lng)
# Out:
# 37.2967198664476 127.06861385175
# 37.234316688001 127.1890469867
# 0.0 0.0
# 37.3029740213321 127.106124967698
# 37.254704374952 127.110523825053
# 37.2296719610395 127.282100411513
# 37.2689447743636 127.129897999787
# 37.2787338024996 127.131088739844
# 37.295534418755 127.149523802711
# 0.0 0.0
# 0.0 0.0
# 37.279797933497 127.148411081312
# 37.2844229383667 127.143164923122
# 37.2194476697904 127.094770082814
# 37.2514394476699 127.137686667204
# 37.2327171416241 127.071818048735
# 37.2784107788257 127.106386122259
# 37.2729783931728 127.10975914703
# 37.307247450943 127.111802570007
# 37.2742584953919 127.140382259308
# 37.2794974792399 127.109982854217
# 37.2211327002552 127.111648412556
# 37.3207243639462 127.110784921318
# 37.2390627712733 127.107802867191
# 37.2537492240619 127.112580141379
# 37.2465029840082 127.102302526191
# 37.3597891030811 127.056610118809
# 37.3284925772716 127.114980475059
# 37.3381482519719 127.090786355455
# 37.3329514491264 127.096389199643
# ...

# %%
print(lat,lng)
# Out:
# 37.3362712189489 127.196479952972

# %%
for i in items:
    iat = i.get('lat')
    lng = i.get('lng')
    print(lat,lng)
# Out:
# 37.3362712189489 127.06861385175
# 37.3362712189489 127.1890469867
# 37.3362712189489 0.0
# 37.3362712189489 127.106124967698
# 37.3362712189489 127.110523825053
# 37.3362712189489 127.282100411513
# 37.3362712189489 127.129897999787
# 37.3362712189489 127.131088739844
# 37.3362712189489 127.149523802711
# 37.3362712189489 0.0
# 37.3362712189489 0.0
# 37.3362712189489 127.148411081312
# 37.3362712189489 127.143164923122
# 37.3362712189489 127.094770082814
# 37.3362712189489 127.137686667204
# 37.3362712189489 127.071818048735
# 37.3362712189489 127.106386122259
# 37.3362712189489 127.10975914703
# 37.3362712189489 127.111802570007
# 37.3362712189489 127.140382259308
# 37.3362712189489 127.109982854217
# 37.3362712189489 127.111648412556
# 37.3362712189489 127.110784921318
# 37.3362712189489 127.107802867191
# 37.3362712189489 127.112580141379
# 37.3362712189489 127.102302526191
# 37.3362712189489 127.056610118809
# 37.3362712189489 127.114980475059
# ...

# %% [markdown]
# # 인디언식 이름 짓기
